# %% [markdown]
# <a href="https://colab.research.google.com/github/Aayushma24/Numerical-methods/blob/master/PYTHON0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#List Comprehension
square=[num**2 for num in range (0,10)]
print(square)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
colors={'rojo':"red",2:5,3:"green"}
colors
# Out:
# {'rojo': 'red', 2: 5, 3: 'green'}

# %%
colors[3]
# Out:
# 'green'

# %%
colors[3]=10#append
colors
# Out:
# {'rojo': 'red', 2: 5, 3: 10}

# %%
random={1:'red',2:'pink',3:["black","white","red"]}
random
# Out:
# {1: 'red', 2: 'pink', 3: ['black', 'white', 'red']}

# %%
random[3]
# Out:
# ['black', 'white', 'red']

# %%
random
# Out:
# {1: 'red', 2: 'pink', 3: ['black', 'white', 'red']}

# %%
random[3].remove('white')

# %%
random
# Out:
# {1: 'red', 2: 'pink', 3: []}

# %%
#Tuples
#immutable
#heterogeneous
# cannot be changeable

# %%
#creating tuples
colors=(1,2,3.4)

# %%
colors
# Out:
# (1, 2, 3.4)

# %%
#SETS
#creating a set
random=[1,2,3,4,4]
set(random)
# Out:
# {1, 2, 3, 4}

# %%
#pass string as string is iterable
name="harryH"
name_set=set(name)
color='red'
color_set=set(color)
name_set.union(color_set)
# Out:
# {'H', 'a', 'd', 'e', 'h', 'r', 'y'}

# %%
#For loop
colors=['red','green','pink','white']
for color in colors:
  print(color)
# Out:
# red
# green
# pink
# white

# %%
point=[(1,2),(3,4),(5,6),(7,8)]
for x,y in point:
  print(f"{x=} and {y=}")
# Out:
# x=1 and y=2
# x=3 and y=4
# x=5 and y=6
# x=7 and y=8

# %%
student={
    "Alice":66.7,
    "Abi":78.9,
    "Sameer":45.67,
    "Aadhunik":34.5,
}
for students in student:
  print(students)
# Out:
# Alice
# Abi
# Sameer
# Aadhunik

# %%
print(student)
# Out:
# {'Alice': 66.7, 'Abi': 78.9, 'Sameer': 45.67, 'Aadhunik': 34.5}

# %%
#Lambda Function
def identity(x):
  return x

# %%
(lambda x:x+1)(2)
# Out:
# 3

# %%
(lambda x:
 (x%2 and 'odd' or 'evem'))(3)
# Out:
# 'odd'

# %%
sum_of_two_nums = lambda c,d: c + d

sum_of_two_nums(4,5)
# Out:
# 9

# %%
#Map function
def cubic(number):
 return number **3
num_list = [0,1,2,3,4]
list(map(cubic,num_list))
# Out:
# [0, 1, 8, 27, 64]

# %%
#Filter function
def odd_check(number):
 return number % 2!=0
 numb_list=[1,2,3,4,5,6,7,8,9]
 list(filter(odd_check,num_list))
